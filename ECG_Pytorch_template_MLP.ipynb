# %% [markdown]
# ### Build a DNN for ECG Signal Classification (5 classes)  - Pytorch
# This is the implementation of an MLP for classifying the ECG signals. <br>
# Your task is to design new DNNs for ECG signal classification <br>
# You can use this file as a template

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as nnF
from torch.utils.data import DataLoader as torch_dataloader
from torch.utils.data import Dataset as torch_dataset
import torch.optim as optim

# %% [markdown]
# ## The Neural Network: MLP  (Replace this with your CNN and rename the file)

# %%
class step3(nn.Module):
    def __init__(self):
        super().__init__() 
        self.linear3 = nn.Linear(in_features=128, out_features=64)
        self.bn3 = nn.BatchNorm1d(num_features=128)
        self.pool = torch.nn.AvgPool1d(2, stride=2, padding=0)
        
    def forward(self,x): 
        x1 = self.bn3(x)
        x1=self.linear3(x1)
        x1 = nnF.relu(x1)
        z= self.pool(x)
        print(z.shape)
        x  = x1+z
        return x

class step4(nn.Module):
    def __init__(self):
        super().__init__() 
        self.bn4 = nn.BatchNorm1d(num_features=64)
        self.linear4 = nn.Linear(in_features=64, out_features=32)
        self.pool = torch.nn.AvgPool1d(2, stride=2, padding=0)
        
    def forward(self,x): 
        x2 = self.bn4(x)
        x2=self.linear4(x2)
        x2 = nnF.relu(x2)
        z= self.pool(x)
        x  = x2+z
        return x
        
class step5(nn.Module):
    def __init__(self):
        super().__init__() 
        self.bn5 = nn.BatchNorm1d(num_features = 32)
        self.linear5 = nn.Linear(32, 16)
        
    def forward(self,x): 
        x = self.bn5(x)
        x=self.linear5(x)
        x = nnF.relu(x)
        return x        
# class step4(nn.Module):
    
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear1 = nn.Linear(in_features=187, out_features=256)
        self.linear2 = nn.Linear(in_features=256, out_features=128)
        self.linear6 = nn.Linear(16, 5) 
        self.step3 = step3()
        self.step4 = step4()
        self.step5 = step5()
        self.pool = torch.nn.AvgPool1d(2, stride=2, padding=0)
    def forward(self, x):
        x = nnF.relu(self.linear1(x))
        y = nnF.relu(self.linear2(x))
        z = self.pool(x)
        x  = y+z
        x = self.step3(x)
        x = self.step4(x)
        x = self.step5(x)
        
        x =self.linear6(x)
        z = x 
        
        return z
        #y=nnF.softmax(z, dim=1)

# %%
#debug your network here
#make sure it works for one single input sample
model=Net()
x=torch.rand(2,187)
#x=torch.rand(10,1,187) if network is CNN
z=model(x)
# Out:
# torch.Size([2, 64])

# %%
def save_checkpoint(filename, model, optimizer, result, epoch):
    torch.save({'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'result':result},
               filename)
    print('saved:', filename)

# %%
def cal_accuracy(confusion):
    #input: confusion is the confusion matrix
    #output: acc is the standard classification accuracy
    M=confusion.copy().astype('float32')
    acc = M.diagonal().sum()/M.sum()    
    sens=np.zeros(M.shape[0])
    prec=np.zeros(M.shape[0]) 
    for n in range(0, M.shape[0]):
        TP=M[n,n]
        FN=np.sum(M[n,:])-TP
        FP=np.sum(M[:,n])-TP
        sens[n]=TP/(TP+FN)
        prec[n]=TP/(TP+FP)       
    return acc, sens, prec

# %% [markdown]
# ## The function to train the model

# %%
def train(model, device, optimizer, dataloader, epoch):    
    model.train()#set model to training mode
    loss_train=0
    acc_train =0 
    sample_count=0
    for batch_idx, (X, Y) in enumerate(dataloader):
        X, Y = X.to(device), Y.to(device)
        optimizer.zero_grad()#clear grad of each parameter
        Z = model(X)#forward pass
        loss = nnF.cross_entropy(Z, Y)
        loss.backward()#backward pass
        optimizer.step()#update parameters
        loss_train+=loss.item()
        #do not need softmax
        Yp = Z.data.max(dim=1)[1]  # get the index of the max               
        acc_train+= torch.sum(Yp==Y).item()
        sample_count+=X.size(0)
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{:.0f}%]\tLoss: {:.6f}'.format(
                    epoch, 100. * batch_idx / len(dataloader), loss.item()))
    loss_train/=len(dataloader)
    #due to upsampling, len(dataloader.dataset) != sample_count
    #acc_train/=len(dataloader.dataset) 
    acc_train/=sample_count    
    return loss_train, acc_train

# %% [markdown]
# ## The Function to test the model

# %%
def test(model, device, dataloader):
    model.eval()#set model to evaluation mode
    acc_test =0
    confusion=np.zeros((5,5))
    with torch.no_grad(): # tell Pytorch not to build graph in the with section
        for batch_idx, (X, Y) in enumerate(dataloader):
            X, Y = X.to(device), Y.to(device)
            Z = model(X)#forward pass
            #do not need softmax
            Yp = Z.data.max(dim=1)[1]  # get the index of the max 
            acc_test+= torch.sum(Yp==Y).item()
            for i in range(0, 5):
                for j in range(0, 5):
                    confusion[i,j]+=torch.sum((Y==i)&(Yp==j)).item()
    acc, sens, prec=cal_accuracy(confusion)
    return acc, (confusion, sens, prec)

# %% [markdown]
# ## Load data and create dataloaders

# %%
class MyDataset(torch_dataset):
    def __init__(self, X, Y):
        self.X=X
        self.Y=Y
    def __len__(self):
        #return the number of data points
        return self.X.shape[0]
    def __getitem__(self, idx):        
        #we can use DatasetName[idx] to get a data point (x,y) with index idx
        x=torch.tensor(self.X[idx], dtype=torch.float32)
        y=torch.tensor(self.Y[idx], dtype=torch.int64)
        #x=x.reshape(1,-1) if network is CNN
        return x, y

# %%
import pandas as pd
X=pd.read_csv('ECG_dataX.csv')
Y=pd.read_csv('ECG_dataY.csv')

# %%
#convert dataframe to numpy array
X=X.values
X.shape
# Out:
# (3841, 187)

# %%
#convert dataframe to numpy array
Y=Y.values
Y.shape
# Out:
# (3841, 1)

# %%
#reshape Y into a 1D array
Y=Y.reshape(-1)
Y.shape
# Out:
# (3841,)

# %%
plt.hist(Y)
# Out:
# (array([800.,   0., 800.,   0.,   0., 800.,   0., 641.,   0., 800.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
fs=125  # sampling frequency
Ts=1/fs # sampling interval
N=187 # the number of timepoints
Duration=N*Ts # duration of a signal
t=np.linspace(0, Duration-Ts, N) # array of timepoints
fig, ax = plt.subplots(5,1,constrained_layout=True, figsize=(10,10))
for c in range(0, 5):   
    for n in range(0, 3):
        idx=np.random.randint(0,10)
        ax[c].plot(t, X[Y==c][idx])        
        ax[c].set_xlabel('time t [seconds]', fontsize=16)
        ax[c].set_ylabel('amplitude', fontsize=16)
    ax[c].set_title('class '+str(c), fontsize=16)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, random_state=0)

# %%
dataset_train=MyDataset(X_train, Y_train)
dataset_val=MyDataset(X_val, Y_val)
dataset_test=MyDataset(X_test, Y_test)

# %%
loader_train = torch_dataloader(dataset_train, batch_size=128, shuffle=False, num_workers=0)
loader_val = torch_dataloader(dataset_val, batch_size=128, shuffle=False, num_workers=0) 
loader_test = torch_dataloader(dataset_test, batch_size=128, shuffle=False, num_workers=0)

# %% [markdown]
# ## Create a model, and start the traning-validation-testing process

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model=Net()
model.to(device)
x=dataset_train[0][0]
x=x.view(1,187).to(device)  #change it to x=x.view(1,1,187).to(device) for CNN
x=x.expand(10,187) 
z=model(x)
# Out:
# torch.Size([10, 64])

# %%
y_hat=nnF.softmax(z, dim=1)
y_hat
# Out:
# tensor([[0.1651, 0.1843, 0.1547, 0.2273, 0.2687],
#         [0.1651, 0.1843, 0.1547, 0.2273, 0.2687],
#         [0.1651, 0.1843, 0.1547, 0.2273, 0.2687],
#         [0.1651, 0.1843, 0.1547, 0.2273, 0.2687],
#         [0.1651, 0.1843, 0.1547, 0.2273, 0.2687],
#         [0.1651, 0.1843, 0.1547, 0.2273, 0.2687],
#         [0.1651, 0.1843, 0.1547, 0.2273, 0.2687],
#         [0.1651, 0.1843, 0.1547, 0.2273, 0.2687],
#         [0.1651, 0.1843, 0.1547, 0.2273, 0.2687],
#         [0.1651, 0.1843, 0.1547, 0.2273, 0.2687]], grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# use stochastic gradient descent as the optimization method

# %%
optimizer = optim.Adamax(model.parameters(), lr=0.001, weight_decay=1e-4)

# %%
loss_train_list=[]
acc_train_list=[]
acc_val_list=[]
epoch_save=-1

# %% [markdown]
# train/val/test over many epochs

# %%
for epoch in range(epoch_save+1, 100): #change 100 to a larger number if necessary
    #-------- training --------------------------------
    loss_train, acc_train =train(model, device, optimizer, loader_train, epoch)    
    loss_train_list.append(loss_train)
    acc_train_list.append(acc_train)
    print('epoch', epoch, 'training loss:', loss_train, 'acc:', acc_train)
    #-------- validation --------------------------------
    acc_val, other_val = test(model, device, loader_val)
    acc_val_list.append(acc_val)
    print('epoch', epoch, 'validation acc:', acc_val)
    #--------save model-------------------------
    result = (loss_train_list, acc_train_list, 
              acc_val_list, other_val)
    save_checkpoint('ECG_MLP_Pytorch_epoch'+str(epoch)+'.pt', model, optimizer, result, epoch)
    epoch_save=epoch
# Out:
# torch.Size([128, 64])
# Train Epoch: 0 [0%]	Loss: 1.673238
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 0 training loss: 1.2282829013737766 acc: 0.5748914616497829
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 0 validation acc: 0.3409091
# saved: ECG_MLP_Pytorch_epoch0.pt
# torch.Size([128, 64])
# Train Epoch: 1 [0%]	Loss: 1.034908
# torch.Size([128, 64])
# /var/folders/8k/1knn1hln20j8lm_mcv4jv_0w0000gn/T/ipykernel_39007/3076453557.py:13: RuntimeWarning: invalid value encountered in float_scalars
#   prec[n]=TP/(TP+FP)
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 1 training loss: 0.8861948468468406 acc: 0.7297395079594791
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 1 validation acc: 0.6948052
# saved: ECG_MLP_Pytorch_epoch1.pt
# torch.Size([128, 64])
# Train Epoch: 2 [0%]	Loss: 0.814842
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 2 training loss: 0.6938663775270636 acc: 0.796671490593343
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 2 validation acc: 0.7694805
# saved: ECG_MLP_Pytorch_epoch2.pt
# torch.Size([128, 64])
# Train Epoch: 3 [0%]	Loss: 0.652893
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 3 training loss: 0.5588219965046103 acc: 0.8324891461649783
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 3 validation acc: 0.78571427
# saved: ECG_MLP_Pytorch_epoch3.pt
# torch.Size([128, 64])
# Train Epoch: 4 [0%]	Loss: 0.543484
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 4 training loss: 0.4639596532691609 acc: 0.8578147612156295
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 4 validation acc: 0.8051948
# saved: ECG_MLP_Pytorch_epoch4.pt
# torch.Size([128, 64])
# Train Epoch: 5 [0%]	Loss: 0.483055
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 5 training loss: 0.3931907442483035 acc: 0.8769898697539797
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 5 validation acc: 0.8181818
# saved: ECG_MLP_Pytorch_epoch5.pt
# torch.Size([128, 64])
# Train Epoch: 6 [0%]	Loss: 0.417428
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 6 training loss: 0.3393408635800535 acc: 0.8954413892908828
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 6 validation acc: 0.8181818
# saved: ECG_MLP_Pytorch_epoch6.pt
# torch.Size([128, 64])
# Train Epoch: 7 [0%]	Loss: 0.364934
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 7 training loss: 0.2936886223879727 acc: 0.9070188133140377
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 7 validation acc: 0.8279221
# saved: ECG_MLP_Pytorch_epoch7.pt
# torch.Size([128, 64])
# Train Epoch: 8 [0%]	Loss: 0.321285
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 8 training loss: 0.254592163996263 acc: 0.9222141823444283
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 8 validation acc: 0.83441556
# saved: ECG_MLP_Pytorch_epoch8.pt
# torch.Size([128, 64])
# Train Epoch: 9 [0%]	Loss: 0.263841
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 9 training loss: 0.2217706502838568 acc: 0.9327062228654125
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 9 validation acc: 0.8214286
# saved: ECG_MLP_Pytorch_epoch9.pt
# torch.Size([128, 64])
# Train Epoch: 10 [0%]	Loss: 0.220541
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 10 training loss: 0.19164846295660193 acc: 0.9468162083936325
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 10 validation acc: 0.8181818
# saved: ECG_MLP_Pytorch_epoch10.pt
# torch.Size([128, 64])
# Train Epoch: 11 [0%]	Loss: 0.178381
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 11 training loss: 0.16516565158963203 acc: 0.9602026049204052
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 11 validation acc: 0.83766234
# saved: ECG_MLP_Pytorch_epoch11.pt
# torch.Size([128, 64])
# Train Epoch: 12 [0%]	Loss: 0.155543
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 12 training loss: 0.14311976155096834 acc: 0.9670767004341534
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 12 validation acc: 0.83766234
# saved: ECG_MLP_Pytorch_epoch12.pt
# torch.Size([128, 64])
# Train Epoch: 13 [0%]	Loss: 0.137850
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 13 training loss: 0.13071978159926154 acc: 0.9688856729377714
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 13 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch13.pt
# torch.Size([128, 64])
# Train Epoch: 14 [0%]	Loss: 0.106357
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 14 training loss: 0.1118167315355756 acc: 0.975397973950796
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 14 validation acc: 0.84090906
# saved: ECG_MLP_Pytorch_epoch14.pt
# torch.Size([128, 64])
# Train Epoch: 15 [0%]	Loss: 0.096475
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 15 training loss: 0.09987062503668395 acc: 0.9801013024602026
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 15 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch15.pt
# torch.Size([128, 64])
# Train Epoch: 16 [0%]	Loss: 0.082380
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 16 training loss: 0.08593982000919906 acc: 0.9829956584659914
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 16 validation acc: 0.83441556
# saved: ECG_MLP_Pytorch_epoch16.pt
# torch.Size([128, 64])
# Train Epoch: 17 [0%]	Loss: 0.073948
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 17 training loss: 0.07380592450499535 acc: 0.9862518089725036
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 17 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch17.pt
# torch.Size([128, 64])
# Train Epoch: 18 [0%]	Loss: 0.069236
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 18 training loss: 0.06022069594738158 acc: 0.9902315484804631
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 18 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch18.pt
# torch.Size([128, 64])
# Train Epoch: 19 [0%]	Loss: 0.063235
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 19 training loss: 0.05053578291765668 acc: 0.9916787264833574
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 19 validation acc: 0.84090906
# saved: ECG_MLP_Pytorch_epoch19.pt
# torch.Size([128, 64])
# Train Epoch: 20 [0%]	Loss: 0.034628
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 20 training loss: 0.04250685625116934 acc: 0.9949348769898697
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 20 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch20.pt
# torch.Size([128, 64])
# Train Epoch: 21 [0%]	Loss: 0.031612
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 21 training loss: 0.03838516212999821 acc: 0.9949348769898697
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 21 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch21.pt
# torch.Size([128, 64])
# Train Epoch: 22 [0%]	Loss: 0.029032
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 22 training loss: 0.03418270176784559 acc: 0.9967438494934877
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 22 validation acc: 0.84090906
# saved: ECG_MLP_Pytorch_epoch22.pt
# torch.Size([128, 64])
# Train Epoch: 23 [0%]	Loss: 0.033294
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 23 training loss: 0.0325629737820815 acc: 0.9956584659913169
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 23 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch23.pt
# torch.Size([128, 64])
# Train Epoch: 24 [0%]	Loss: 0.024221
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 24 training loss: 0.031105598773468624 acc: 0.9952966714905933
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 24 validation acc: 0.84090906
# saved: ECG_MLP_Pytorch_epoch24.pt
# torch.Size([128, 64])
# Train Epoch: 25 [0%]	Loss: 0.027891
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 25 training loss: 0.03099861271171407 acc: 0.993849493487699
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 25 validation acc: 0.8279221
# saved: ECG_MLP_Pytorch_epoch25.pt
# torch.Size([128, 64])
# Train Epoch: 26 [0%]	Loss: 0.017377
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 26 training loss: 0.027467472521080213 acc: 0.9949348769898697
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 26 validation acc: 0.8538961
# saved: ECG_MLP_Pytorch_epoch26.pt
# torch.Size([128, 64])
# Train Epoch: 27 [0%]	Loss: 0.019645
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 27 training loss: 0.027733709451488474 acc: 0.9942112879884226
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 27 validation acc: 0.85714287
# saved: ECG_MLP_Pytorch_epoch27.pt
# torch.Size([128, 64])
# Train Epoch: 28 [0%]	Loss: 0.027437
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 28 training loss: 0.025854938155548138 acc: 0.9956584659913169
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 28 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch28.pt
# torch.Size([128, 64])
# Train Epoch: 29 [0%]	Loss: 0.022893
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 29 training loss: 0.029905777170576832 acc: 0.9927641099855282
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 29 validation acc: 0.8246753
# saved: ECG_MLP_Pytorch_epoch29.pt
# torch.Size([128, 64])
# Train Epoch: 30 [0%]	Loss: 0.020506
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 30 training loss: 0.030674499184401197 acc: 0.9945730824891461
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 30 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch30.pt
# torch.Size([128, 64])
# Train Epoch: 31 [0%]	Loss: 0.011514
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 31 training loss: 0.022951867050406607 acc: 0.9945730824891461
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 31 validation acc: 0.8279221
# saved: ECG_MLP_Pytorch_epoch31.pt
# torch.Size([128, 64])
# Train Epoch: 32 [0%]	Loss: 0.014058
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 32 training loss: 0.019060388292101296 acc: 0.9960202604920405
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 32 validation acc: 0.84090906
# saved: ECG_MLP_Pytorch_epoch32.pt
# torch.Size([128, 64])
# Train Epoch: 33 [0%]	Loss: 0.021808
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 33 training loss: 0.01692521817643534 acc: 0.9971056439942113
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 33 validation acc: 0.83766234
# saved: ECG_MLP_Pytorch_epoch33.pt
# torch.Size([128, 64])
# Train Epoch: 34 [0%]	Loss: 0.016098
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 34 training loss: 0.014349056915803389 acc: 0.9978292329956585
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 34 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch34.pt
# torch.Size([128, 64])
# Train Epoch: 35 [0%]	Loss: 0.011670
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 35 training loss: 0.01452552696520632 acc: 0.9967438494934877
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 35 validation acc: 0.84090906
# saved: ECG_MLP_Pytorch_epoch35.pt
# torch.Size([128, 64])
# Train Epoch: 36 [0%]	Loss: 0.007721
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 36 training loss: 0.017116617220877248 acc: 0.9960202604920405
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 36 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch36.pt
# torch.Size([128, 64])
# Train Epoch: 37 [0%]	Loss: 0.016462
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 37 training loss: 0.015639248917895286 acc: 0.9978292329956585
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 37 validation acc: 0.8214286
# saved: ECG_MLP_Pytorch_epoch37.pt
# torch.Size([128, 64])
# Train Epoch: 38 [0%]	Loss: 0.007724
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 38 training loss: 0.01952262248166583 acc: 0.9963820549927641
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 38 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch38.pt
# torch.Size([128, 64])
# Train Epoch: 39 [0%]	Loss: 0.007801
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 39 training loss: 0.0139318204336715 acc: 0.9974674384949349
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 39 validation acc: 0.83116883
# saved: ECG_MLP_Pytorch_epoch39.pt
# torch.Size([128, 64])
# Train Epoch: 40 [0%]	Loss: 0.051237
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 40 training loss: 0.015137497780167243 acc: 0.9974674384949349
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 40 validation acc: 0.8246753
# saved: ECG_MLP_Pytorch_epoch40.pt
# torch.Size([128, 64])
# Train Epoch: 41 [0%]	Loss: 0.009245
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 41 training loss: 0.01940979233900593 acc: 0.9952966714905933
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 41 validation acc: 0.83116883
# saved: ECG_MLP_Pytorch_epoch41.pt
# torch.Size([128, 64])
# Train Epoch: 42 [0%]	Loss: 0.006529
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 42 training loss: 0.010711821261793375 acc: 0.9978292329956585
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 42 validation acc: 0.83441556
# saved: ECG_MLP_Pytorch_epoch42.pt
# torch.Size([128, 64])
# Train Epoch: 43 [0%]	Loss: 0.005785
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 43 training loss: 0.007087666816501455 acc: 0.9992764109985528
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 43 validation acc: 0.83441556
# saved: ECG_MLP_Pytorch_epoch43.pt
# torch.Size([128, 64])
# Train Epoch: 44 [0%]	Loss: 0.003573
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 44 training loss: 0.0047834058482707905 acc: 0.9996382054992764
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 44 validation acc: 0.8538961
# saved: ECG_MLP_Pytorch_epoch44.pt
# torch.Size([128, 64])
# Train Epoch: 45 [0%]	Loss: 0.003264
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 45 training loss: 0.005152857793622057 acc: 0.9996382054992764
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 45 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch45.pt
# torch.Size([128, 64])
# Train Epoch: 46 [0%]	Loss: 0.002910
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 46 training loss: 0.0042561495845968075 acc: 0.9996382054992764
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 46 validation acc: 0.85714287
# saved: ECG_MLP_Pytorch_epoch46.pt
# torch.Size([128, 64])
# Train Epoch: 47 [0%]	Loss: 0.002682
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 47 training loss: 0.0038017437645149503 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 47 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch47.pt
# torch.Size([128, 64])
# Train Epoch: 48 [0%]	Loss: 0.002351
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 48 training loss: 0.002823153547730974 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 48 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch48.pt
# torch.Size([128, 64])
# Train Epoch: 49 [0%]	Loss: 0.002245
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 49 training loss: 0.003427164962472902 acc: 0.9992764109985528
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 49 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch49.pt
# torch.Size([128, 64])
# Train Epoch: 50 [0%]	Loss: 0.002336
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 50 training loss: 0.003132285640193996 acc: 0.9996382054992764
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 50 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch50.pt
# torch.Size([128, 64])
# Train Epoch: 51 [0%]	Loss: 0.002041
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 51 training loss: 0.0029130329706028783 acc: 0.9996382054992764
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 51 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch51.pt
# torch.Size([128, 64])
# Train Epoch: 52 [0%]	Loss: 0.002032
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 52 training loss: 0.004095771201801571 acc: 0.9996382054992764
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 52 validation acc: 0.8538961
# saved: ECG_MLP_Pytorch_epoch52.pt
# torch.Size([128, 64])
# Train Epoch: 53 [0%]	Loss: 0.002136
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 53 training loss: 0.003331176582088863 acc: 0.9996382054992764
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 53 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch53.pt
# torch.Size([128, 64])
# Train Epoch: 54 [0%]	Loss: 0.001933
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 54 training loss: 0.002871378742962737 acc: 0.9996382054992764
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 54 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch54.pt
# torch.Size([128, 64])
# Train Epoch: 55 [0%]	Loss: 0.001725
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 55 training loss: 0.0026723035896958954 acc: 0.9996382054992764
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 55 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch55.pt
# torch.Size([128, 64])
# Train Epoch: 56 [0%]	Loss: 0.001897
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 56 training loss: 0.003190749446565116 acc: 0.9992764109985528
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 56 validation acc: 0.84090906
# saved: ECG_MLP_Pytorch_epoch56.pt
# torch.Size([128, 64])
# Train Epoch: 57 [0%]	Loss: 0.001976
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 57 training loss: 0.002701299735979939 acc: 0.9996382054992764
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 57 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch57.pt
# torch.Size([128, 64])
# Train Epoch: 58 [0%]	Loss: 0.001690
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 58 training loss: 0.002708509900416671 acc: 0.9996382054992764
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 58 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch58.pt
# torch.Size([128, 64])
# Train Epoch: 59 [0%]	Loss: 0.001707
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 59 training loss: 0.0028975816967431456 acc: 0.9992764109985528
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 59 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch59.pt
# torch.Size([128, 64])
# Train Epoch: 60 [0%]	Loss: 0.001528
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 60 training loss: 0.0021234695609150963 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 60 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch60.pt
# torch.Size([128, 64])
# Train Epoch: 61 [0%]	Loss: 0.001571
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 61 training loss: 0.002600213041825389 acc: 0.9996382054992764
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 61 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch61.pt
# torch.Size([128, 64])
# Train Epoch: 62 [0%]	Loss: 0.001741
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 62 training loss: 0.002426845169710842 acc: 0.9996382054992764
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 62 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch62.pt
# torch.Size([128, 64])
# Train Epoch: 63 [0%]	Loss: 0.001512
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 63 training loss: 0.002771406201645732 acc: 0.9992764109985528
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 63 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch63.pt
# torch.Size([128, 64])
# Train Epoch: 64 [0%]	Loss: 0.001615
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 64 training loss: 0.004046300209169699 acc: 0.9992764109985528
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 64 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch64.pt
# torch.Size([128, 64])
# Train Epoch: 65 [0%]	Loss: 0.001623
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 65 training loss: 0.002483877567680214 acc: 0.9996382054992764
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 65 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch65.pt
# torch.Size([128, 64])
# Train Epoch: 66 [0%]	Loss: 0.001397
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# ...
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 77 training loss: 0.004241822440896861 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 77 validation acc: 0.84090906
# saved: ECG_MLP_Pytorch_epoch77.pt
# torch.Size([128, 64])
# Train Epoch: 78 [0%]	Loss: 0.002609
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 78 training loss: 0.0038887812988832593 acc: 0.9996382054992764
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 78 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch78.pt
# torch.Size([128, 64])
# Train Epoch: 79 [0%]	Loss: 0.001455
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 79 training loss: 0.0025761952115730805 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 79 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch79.pt
# torch.Size([128, 64])
# Train Epoch: 80 [0%]	Loss: 0.002454
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 80 training loss: 0.0015480765750081364 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 80 validation acc: 0.8538961
# saved: ECG_MLP_Pytorch_epoch80.pt
# torch.Size([128, 64])
# Train Epoch: 81 [0%]	Loss: 0.000960
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 81 training loss: 0.0009606241589856588 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 81 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch81.pt
# torch.Size([128, 64])
# Train Epoch: 82 [0%]	Loss: 0.000874
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 82 training loss: 0.0008329503656237979 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 82 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch82.pt
# torch.Size([128, 64])
# Train Epoch: 83 [0%]	Loss: 0.000755
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 83 training loss: 0.0007601761343804272 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 83 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch83.pt
# torch.Size([128, 64])
# Train Epoch: 84 [0%]	Loss: 0.000693
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 84 training loss: 0.000712877970231189 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 84 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch84.pt
# torch.Size([128, 64])
# Train Epoch: 85 [0%]	Loss: 0.000651
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 85 training loss: 0.0006756056695435705 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 85 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch85.pt
# torch.Size([128, 64])
# Train Epoch: 86 [0%]	Loss: 0.000618
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 86 training loss: 0.00064404517152897 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 86 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch86.pt
# torch.Size([128, 64])
# Train Epoch: 87 [0%]	Loss: 0.000591
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 87 training loss: 0.0006166787722825327 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 87 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch87.pt
# torch.Size([128, 64])
# Train Epoch: 88 [0%]	Loss: 0.000567
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 88 training loss: 0.0005921275587752461 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 88 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch88.pt
# torch.Size([128, 64])
# Train Epoch: 89 [0%]	Loss: 0.000547
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 89 training loss: 0.0005703013686632568 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 89 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch89.pt
# torch.Size([128, 64])
# Train Epoch: 90 [0%]	Loss: 0.000528
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 90 training loss: 0.0005500705843918364 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 90 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch90.pt
# torch.Size([128, 64])
# Train Epoch: 91 [0%]	Loss: 0.000510
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 91 training loss: 0.0005318805593891408 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 91 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch91.pt
# torch.Size([128, 64])
# Train Epoch: 92 [0%]	Loss: 0.000495
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 92 training loss: 0.0005148622228510001 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 92 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch92.pt
# torch.Size([128, 64])
# Train Epoch: 93 [0%]	Loss: 0.000481
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 93 training loss: 0.000499048419772986 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 93 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch93.pt
# torch.Size([128, 64])
# Train Epoch: 94 [0%]	Loss: 0.000468
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 94 training loss: 0.00048388716161505067 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 94 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch94.pt
# torch.Size([128, 64])
# Train Epoch: 95 [0%]	Loss: 0.000454
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 95 training loss: 0.0004700078954391012 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 95 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch95.pt
# torch.Size([128, 64])
# Train Epoch: 96 [0%]	Loss: 0.000442
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 96 training loss: 0.00045715012211902916 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 96 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch96.pt
# torch.Size([128, 64])
# Train Epoch: 97 [0%]	Loss: 0.000431
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 97 training loss: 0.0004450460189466619 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 97 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch97.pt
# torch.Size([128, 64])
# Train Epoch: 98 [0%]	Loss: 0.000421
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 98 training loss: 0.0004333019314799458 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 98 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch98.pt
# torch.Size([128, 64])
# Train Epoch: 99 [0%]	Loss: 0.000410
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([76, 64])
# epoch 99 training loss: 0.0004223191724370488 acc: 1.0
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([52, 64])
# epoch 99 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch99.pt

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6))
ax[0].set_title('loss v.s. epoch',fontsize=16)
ax[0].plot(loss_train_list, '-b', label='training loss')
ax[0].set_xlabel('epoch',fontsize=16)
ax[0].legend(fontsize=16)
ax[0].grid(True)
ax[1].set_title('accuracy v.s. epoch',fontsize=16)
ax[1].plot(acc_train_list, '-b', label='training accuracy')
ax[1].plot(acc_val_list, '-g', label='validation accuracy')
ax[1].set_xlabel('epoch',fontsize=16)
ax[1].legend(fontsize=16)
ax[1].grid(True)

# %% [markdown]
# load the best model

# %%
best_epoch=np.argmax(acc_val_list)
best_epoch
# Out:
# 73

# %%
checkpoint=torch.load('ECG_MLP_Pytorch_epoch'+str(best_epoch)+'.pt')
model=Net()
model.load_state_dict(checkpoint['model_state_dict'])
model.to(device);
model.eval();

# %%
acc, (confusion, sens, prec) = test(model, device, loader_test)
print('Accuracy (average)', acc)
print('Sensitivity', sens)
print('Precision', prec)
print('Confusion \n', confusion)
# Out:
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([128, 64])
# torch.Size([1, 64])
# Accuracy (average) 0.8816645
# Sensitivity [0.78977275 0.90909094 0.87671232 0.90163934 0.94152045]
# Precision [0.82248521 0.83333331 0.92086333 0.90163934 0.94152045]
# Confusion
#  [[139.  20.   6.   5.   6.]
#  [ 10. 140.   3.   0.   1.]
#  [  8.   2. 128.   7.   1.]
#  [  8.   0.   2. 110.   2.]
#  [  4.   6.   0.   0. 161.]]
